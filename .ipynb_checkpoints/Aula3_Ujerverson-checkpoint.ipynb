# %% [markdown]
# Exercício 1: crei um programa que mostre na tela

# %%
print("Eu estou aprendendo python")
# Out:
# Eu estou aprendendo python

# %% [markdown]
# Exercício 2: Crie um programa que mostre:

# %%
print("Meu nome é Maria")
print("Eu moro em Recife")
# Out:
# Meu nome é Maria
# Eu moro em Recife

# %% [markdown]
# Exercício 3: Crie duas variáveis: nome_do_aluno e idade_do_aluno. Depois mostrea na tela: " Meu nome é Ana e tenho 18 anos "

# %%
j = input("Diga seu nome: ")
p = input("Digite sua idade: ")

print("Meu nome é ",j," e tenho ", p)
# Out:
# Diga seu nome:  João
# Digite sua idade:  18
# Meu nome é  João  e tenho  18

# %% [markdown]
# Exercício 4: Crie três variáveis: <font color="green">cidade,estado e pais</font>. E mostre: "Eu moro em Salvador - BA, Brasil"

# %%
pais = input("Qual país você mora: ")
estado = input("Qual estado: ")
cidade = input("Qual cidade: ")

print("Eu moro em ", cidade,"-", estado,",", pais)
# Out:
# Qual país você mora:  Brasil
# Qual estado:  Goiás
# Qual cidade:  Goiânia
# Eu moro em  Goiânia - Goiás , Brasil

# %% [markdown]
# Crie um programa que:
#  1. Pergunte o nome do aluno.
#  2. Pergunte a cidade onde ele mora
#  3. Mostre a frase: Olá João, você mora em Curitiba

# %%
nome = input("Qual o seu nome")
cidade= input("Qual a sua cidade")
print(f"Olá {nome}, você mora em {cidade}")
# Out:
# Qual o seu nome João
# Qual a sua cidade Goiânia
# Olá João, você mora em Goiânia

# %% [markdown]
# # Mais uma vez!
