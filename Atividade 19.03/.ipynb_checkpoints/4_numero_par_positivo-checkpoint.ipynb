# %%
num = int(input("Informe um número-->"))
# Out:
# Informe um número--> -1

# %%
if num > 0:
    if num % 2 == 0:
        print("Par positivio")
    else:
        print("Ímpar positivo")
else:
    print("Número negativo")
# Out:
# Número negativo
