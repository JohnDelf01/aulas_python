# %%
age = int(input("Informe sua idade --> "))
# Out:
# Informe sua idade -->  60

# %%
if age >= 60:
    pain = input("Você sente alguma dor? s/n")
    if pain == "s":
        print("X======= ATENDIMENTO PRIORITÁRIO IMEDIATO =======X")
    elif pain == "S":
        print("X======= ATENDIMENTO PRIORITÁRIO IMEDIATO =======X")
    elif pain == "n":
        print("Aguardar triagem....")
    if pain == "N":
        print("Aguardar triagem....")
else:
    print("|------Atendimento comum------|")
# Out:
# Você sente alguma dor? s/n N
# Aguardar triagem....
