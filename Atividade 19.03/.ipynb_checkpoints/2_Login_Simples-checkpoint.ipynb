# %%
user = input("======Digite o usuário======\n")
# Out:
# ======Digite o usuário======
#  admin

# %%
if user == "admin":
    password = int(input("======Insera a senha======\n"))
    if password == 1234:
        print("\n======Acesso liberado======")
    else:
        print("X---Senha incorreta---X")
else:
    print("X---Usuário incorreto---X")
# Out:
# ======Insera a senha======
#  1234
# ======Acesso liberado======
