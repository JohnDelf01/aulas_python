# %%
age = int(input("======Informe sua idade======"))
print("Você está com seu documento?\n 1 para sim\n 0 para Não\n")
document = str(input())
# Out:
# ======Informe sua idade====== 16
# Você está com seu documento?
#  1 para sim
#  0 para Não
#  0

# %%
if age >= 16:
    if document == "1":
        print("Entrada permitida")
    if document == "0":
        print("Precisa do documento para a entrada")
else:
    print("Entrada não permitida")
# Out:
# Precisa do documento para a entrada
