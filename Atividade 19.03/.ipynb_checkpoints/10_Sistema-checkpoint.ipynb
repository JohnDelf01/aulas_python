# %%
user = input("Digite o nome do usuário: ")
# Out:
# Digite o nome do usuário:  alo

# %%
if user == "professor":
    password = input("Digite a senha do usuário: ")
    if password == "python123":
        level = int(input("Digite o nível de acesso: "))
        if level == 1:
            print("|-Acesso básico-|")
        else:
            print("|-Acesso avançado-|")
    else:
        print("Senha inválida")
else:
    print("Usuário incorreto")
# Out:
# Usuário incorreto
